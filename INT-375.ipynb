# %%
'''meaning=pd.Series(42, ["life","universe","everything"])
print(meaning)'''

#series can have a name
'''s6=pd.Series([83,68], index=["bob","alice"], name="weights")
print(s6)''' 

#plotting a series
'''%matplotlib inline
import matplotlib.pyplot as plt 
temperatures = [4.4, 4.5, 4.6, 5.2, 4.2, 7.5,6.4,4.9]
s7=pd.Series(temperatures, name="Temperature")
s7.plot()
plt.show()'''

#pass a dictionary of series objects
'''people_dict={"wieght": pd.Series([68,83,112],index=["alice","bob","charles"]),
"birthyear":pd.Series([1984,1985,1992], index=["bob","alice","charles"],name="year"),
"children":pd.Series()
}'''

#matplotlib-pylot module 

'''import matplotlib.pyplot as plt 
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()''' 

'''import matplotlib.pyplot as plt 
x=[21,22,23,4,5,6,7,8,54,456,677,4,33,77,99,100]
num_bins=5
plt.hist(x, num_bins, facecolor='blue')
plt.show''' 


'''import pandas as pd 
import os 
HOUSING_PATH='datasets/housing/'

def load_housing_data(housing_path=HOUSING_PATH)
'''

#Scenario based question
#Q1
'''import numpy as np 

sales_data=np.array([
    [10,12,15,14,13,16,18],
    [8,9,11,10,12,14,13],
    [15,17,14,13,19,21,20],
    [7,6,8,9,10,12,11],
    [14,13,12,15,16,18,17]
    ])

print("T1: Average of data per store: ",np.mean(sales_data,axis=1))
print("T2: Total no. of sales: ",np.sum(sales_data,axis=0))
x=np.sum(sales_data,axis=0)
print("T3: Day with highest sales: ",np.argmax(x)+1)

print("Highest sales over a week: ",np.max(x))
total=np.sum(sales_data)
normalized=(sales_data/total)*100
print("T4: Normalized Sales Data (%): ",normalized)

'''
#Q2
'''import pandas as pd
df = pd.read_excel('Pandas.xlsx')
print(df.head())'''

# %%
#pandas aggregate

'''import pandas as pd

user=pd.read_csv("page_visits.csv")

print(user.head())

click=user.groupby("month").id.count().reset_index()
print(click)

source=user.groupby(['utm_source','month']).id.count.reset_index()
print(source)

month=user.groupby(['utm_source','month']).id.count().reset_index()
print(month)

pivots=month.pivot(columns="month", index= "utm_source",value)'''
# Out:
#   Cell In[10], line 18
#     pivots=month.pivot(columns="month", index= "utm_source",value)
#                                                                  ^
# SyntaxError: positional argument follows keyword argument

# %%
'''import pandas as pd 

ad_clicks=pd.read_csv("ad_clicks.csv")

print(ad_clicks.head())

v1=ad_clicks.groupby('utm_source').user_id.count().reset_index()
print(v1)

ad_clicks['is_click'] = ~ad_clicks.ad_click_timestamp.isnull()
clicks_by_source=ad_clicks.groupby(['utm_source','is_click']).user_id.count().reset_index()
print(clicks_by_source)

clicks_pivot='''

# %%
'''import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

students= pd.read_csv('students.csv')
students
scores_urban=students.G3[students.address == 'U']
scores_rural=students.G3[students.address == 'R']
scores_urban_mean=np.mean(scores_urban)
scores_rural_mean=np.mean(scores_rural)
scores_urban_mean
scores_rural_mean

scores_urban_median=np.median(scores_urban)
scores_rural_median=np.median(scores_rural)
scores_urban_median
scores_rural_median'''
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[5], line 7
#       3 import seaborn as sns
#       5 import matplotlib.pyplot as plt
# ----> 7 students= pd.read_csv('students.csv')
#       8 students
#       9 scores_urban=students.G3[students.address == 'U']
#
# ...

# %%
'''import pandas as pd 
import matplotlib.pyplot as plt

housing = pd.read_csv('page_visits.csv', encoding='utf-8')
print(housing.head())
'''

# %%
'''import numpy as np
import pandas as pd 
from scipy.stats import binom_test

p_value_2sided = binom_test(41,500,0.1)

print(p_value_2sided) 

def simulation_binomisl_test(observed_successes, n, p) :
    null_outcomes = []

    for i in range(10000):
        simulated_monthly_visitors = np.random.choice(['y', 'n'], size)'''
